# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Surabhi Zanwar

# %%
Data Analyst

# %% [markdown]
# _I am interested in data science because I like solving problems_

# %% [markdown]
# ### The code is supposed to add values

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# - One
# - Two
# - Three

# %% [markdown]
# 4. Four
# 5. Five
# 6. Six

# %% [markdown]
# ![University-Logo.png](attachment:University-Logo.png)
